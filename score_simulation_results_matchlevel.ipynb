# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')
# %matplotlib inline
plt.style.use('ggplot')

from notebook_helpers import plot_bank_and_bets, run_unit_strategy, run_kelly_strategy, get_tournament_results

# %%
tournament_simulation = get_tournament_results("data/simulations/score/match_level/matchlevel_score*.csv", 'data/original/wc_2018_games_real.csv')
# Out:
# Total number of simulations (940800, 12)
# Accuracy: 0.59375

# %%
match_bets = pd.read_csv('data/original/wc_2018_bets.csv')

# %%
y_pred = tournament_simulation["outcome"].values
y_true = tournament_simulation["true_outcome"].values
odds = match_bets[["1", "X", "2"]].values

run_unit_strategy(y_pred, y_true, odds, plot=True)
# Out:
# Profit: 13.5156%
# Balance:  72.65
# 72.649999999999991

# %%
y_pred = tournament_simulation["outcome"].values
y_true = tournament_simulation["true_outcome"].values
odds = match_bets[["1", "X", "2"]].values
probabilities = tournament_simulation[["home_win_prob", "draw_prob", "away_win_prob"]].values
run_kelly_strategy(y_true, odds, probabilities, plot=True, coef=0.3)
# Out:
# Profit: 14.8027%
# Balance:  73.4737387357
# 73.473738735661229
