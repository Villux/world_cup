# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')
# %matplotlib inline
plt.style.use('ggplot')


from simulation.analyse import get_win_probabilities, get_simulations
from features.data_provider import get_feature_columns, get_whole_dataset, set_feature_columns, other_features, feature_columns, player_features
from models.score_model import get_model
from simulation.predictor import MaxProbabilityScorePredictor
from simulation.simulation import run_simulation, run_actual_tournament_simulation
from db.simulation_table import get_simulation_results, delete_all
from bet.unit_strategy import UnitStrategy
from bet.kelly_strategy import KellyStrategy
from notebook_helpers import plot_bank_and_bets, run_score_model_for_features

# %%
def plot(data):
    tournament_simulation = data["simulation"]
    print(f"Accuracy:", sum(tournament_simulation["outcome"] == tournament_simulation["true_outcome"]) / tournament_simulation.shape[0])
    plot_bank_and_bets(data["unit"])
    plot_bank_and_bets(data["kelly"])

# %%
results = {}
n_estimators = 5000

# %%
tournament_template_file = 'data/original/wc_2010_games_real.csv'
match_bet_file = 'data/original/wc_2010_bets.csv'
filter_start = "2010-06-11"

# %%
wc2010 = run_score_model_for_features(feature_columns, filter_start, 
                                      tournament_template_file, match_bet_file, 
                                      n_estimators=n_estimators)

tmp = {}
tmp["simulation"] = wc2010[0]
tmp["unit"] = wc2010[1]
tmp["kelly"] = wc2010[2]
results["WC2010"] = tmp

plot(tmp)
# Out:
# /Users/villetoiviainen/Documents/dev/world_cup/bet/kelly_strategy.py:12: RuntimeWarning: invalid value encountered in log
#   return -(p1 * np.log(1 + o1*a - b - c) + p2 * np.log(1 + o2*b - a - c) + p3*np.log(1 + o3*c - a - b))
# Accuracy: 0.53125

# %%
wc2010 = run_score_model_for_features(other_features, filter_start, 
                                      tournament_template_file, match_bet_file, 
                                      n_estimators=n_estimators)

tmp = {}
tmp["simulation"] = wc2010[0]
tmp["unit"] = wc2010[1]
tmp["kelly"] = wc2010[2]
results["WC2010_other"] = tmp
plot(tmp)
# Out:
# /Users/villetoiviainen/Documents/dev/world_cup/bet/kelly_strategy.py:12: RuntimeWarning: invalid value encountered in log
#   return -(p1 * np.log(1 + o1*a - b - c) + p2 * np.log(1 + o2*b - a - c) + p3*np.log(1 + o3*c - a - b))
# Accuracy: 0.53125

# %%
wc2010 = run_score_model_for_features(player_features, filter_start, 
                                      tournament_template_file, match_bet_file, 
                                      n_estimators=n_estimators)

tmp = {}
tmp["simulation"] = wc2010[0]
tmp["unit"] = wc2010[1]
tmp["kelly"] = wc2010[2]
results["WC2010_player"] = tmp
plot(tmp)
# Out:
# /Users/villetoiviainen/Documents/dev/world_cup/bet/kelly_strategy.py:12: RuntimeWarning: invalid value encountered in log
#   return -(p1 * np.log(1 + o1*a - b - c) + p2 * np.log(1 + o2*b - a - c) + p3*np.log(1 + o3*c - a - b))
# Accuracy: 0.53125

# %%
tournament_template_file = 'data/original/wc_2014_games_real.csv'
match_bet_file = 'data/original/wc_2014_bets.csv'
filter_start = "2014-06-12"

# %%
output = run_score_model_for_features(feature_columns, filter_start, 
                                      tournament_template_file, match_bet_file, 
                                      n_estimators=n_estimators)

tmp = {}
tmp["simulation"] = output[0]
tmp["unit"] = output[1]
tmp["kelly"] = output[2]
results["WC2014"] = tmp

plot(tmp)
# Out:
# /Users/villetoiviainen/Documents/dev/world_cup/bet/kelly_strategy.py:12: RuntimeWarning: invalid value encountered in log
#   return -(p1 * np.log(1 + o1*a - b - c) + p2 * np.log(1 + o2*b - a - c) + p3*np.log(1 + o3*c - a - b))
# Accuracy: 0.578125

# %%
output = run_score_model_for_features(other_features, filter_start, 
                                      tournament_template_file, match_bet_file, 
                                      n_estimators=n_estimators)

tmp = {}
tmp["simulation"] = output[0]
tmp["unit"] = output[1]
tmp["kelly"] = output[2]
results["WC2014_other"] = tmp

plot(tmp)
# Out:
# /Users/villetoiviainen/Documents/dev/world_cup/bet/kelly_strategy.py:12: RuntimeWarning: invalid value encountered in log
#   return -(p1 * np.log(1 + o1*a - b - c) + p2 * np.log(1 + o2*b - a - c) + p3*np.log(1 + o3*c - a - b))
# Accuracy: 0.59375

# %%
output = run_score_model_for_features(player_features, filter_start, 
                                      tournament_template_file, match_bet_file, 
                                      n_estimators=n_estimators)

tmp = {}
tmp["simulation"] = output[0]
tmp["unit"] = output[1]
tmp["kelly"] = output[2]
results["WC2014_player"] = tmp

plot(tmp)
# Out:
# /Users/villetoiviainen/Documents/dev/world_cup/bet/kelly_strategy.py:12: RuntimeWarning: invalid value encountered in log
#   return -(p1 * np.log(1 + o1*a - b - c) + p2 * np.log(1 + o2*b - a - c) + p3*np.log(1 + o3*c - a - b))
# Accuracy: 0.578125

# %%
tournament_template_file = 'data/original/wc_2018_games_real.csv'
match_bet_file = 'data/original/wc_2018_bets.csv'
filter_start = "2018-06-14"

# %%
output = run_score_model_for_features(feature_columns, filter_start, 
                                      tournament_template_file, match_bet_file, 
                                      n_estimators=n_estimators)

tmp = {}
tmp["simulation"] = output[0]
tmp["unit"] = output[1]
tmp["kelly"] = output[2]
results["WC2018"] = tmp

plot(tmp)
# Out:
# /Users/villetoiviainen/Documents/dev/world_cup/bet/kelly_strategy.py:12: RuntimeWarning: invalid value encountered in log
#   return -(p1 * np.log(1 + o1*a - b - c) + p2 * np.log(1 + o2*b - a - c) + p3*np.log(1 + o3*c - a - b))
# Accuracy: 0.59375

# %%
output = run_score_model_for_features(other_features, filter_start, 
                                      tournament_template_file, match_bet_file, 
                                      n_estimators=n_estimators)

tmp = {}
tmp["simulation"] = output[0]
tmp["unit"] = output[1]
tmp["kelly"] = output[2]
results["WC2018_other"] = tmp

plot(tmp)
# Out:
# /Users/villetoiviainen/Documents/dev/world_cup/bet/kelly_strategy.py:12: RuntimeWarning: invalid value encountered in log
#   return -(p1 * np.log(1 + o1*a - b - c) + p2 * np.log(1 + o2*b - a - c) + p3*np.log(1 + o3*c - a - b))
# /Users/villetoiviainen/Documents/dev/world_cup/bet/kelly_strategy.py:12: RuntimeWarning: divide by zero encountered in log
#   return -(p1 * np.log(1 + o1*a - b - c) + p2 * np.log(1 + o2*b - a - c) + p3*np.log(1 + o3*c - a - b))
# Accuracy: 0.53125

# %%
output = run_score_model_for_features(player_features, filter_start, 
                                      tournament_template_file, match_bet_file, 
                                      n_estimators=n_estimators)

tmp = {}
tmp["simulation"] = output[0]
tmp["unit"] = output[1]
tmp["kelly"] = output[2]
results["WC2018_player"] = tmp

plot(tmp)
# Out:
# /Users/villetoiviainen/Documents/dev/world_cup/bet/kelly_strategy.py:12: RuntimeWarning: invalid value encountered in log
#   return -(p1 * np.log(1 + o1*a - b - c) + p2 * np.log(1 + o2*b - a - c) + p3*np.log(1 + o3*c - a - b))
# Accuracy: 0.625

# %%
for idx, (home_win, draw, away_win) in enumerate(results["WC2018"]["kelly"].get_odds_probabilities_and_fractions()):
    print("GAME", idx)
    print(home_win, draw, away_win)
# Out:
# GAME 0
# (1.46, 0.45993324030377142, 0.0) (4.3399999999999999, 0.2603447492931063, 0.099611866405797014) (9.0700000000000003, 0.2797215238712536, 0.2028107390029838)
# GAME 1
# (8.3599999999999994, 0.20582611089406666, 0.10388121512397382) (4.0999999999999996, 0.25172643719281923, 0.043858318517700078) (1.52, 0.54244650379568271, 0.0)
# GAME 2
# (2.23, 0.45466402053249755, 0.059135871229398604) (2.98, 0.2744733856289242, 0.0) (4.1600000000000001, 0.27086237438659166, 0.058836736124970312)
# GAME 3
# (4.3799999999999999, 0.26786796530300999, 0.05126082982753867) (3.2799999999999998, 0.26775511021209236, 0.0) (2.04, 0.46437659394071623, 0.0)
# GAME 4
# (1.27, 0.62436182315871069, 0.0) (7.2199999999999998, 0.21962976842418633, 0.10662648220671046) (10.390000000000001, 0.15600410960094307, 0.07747863599605416)
# GAME 5
# (1.3300000000000001, 0.60087776929543013, 0.0) (5.4299999999999997, 0.22965075075875516, 0.077460157409645236) (11.27, 0.16946871416542322, 0.09614200502642066)
# ...
